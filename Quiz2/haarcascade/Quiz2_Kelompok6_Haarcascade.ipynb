# %% [markdown]
# # KUIS 2 PEMBELAJARAN MESIN
# Face Detection dan Face Recognition
# # Intro
#
# Pada kuis ini, Anda diminta untuk melakukan face detection dan face recognition pada wajah dengan menggunakan dataset primer (dataset wajah yang kalian kumpulkan sendiri).
# Spesifikasi pengerjaan kuis yang harus dipehuni adalah,
#
# 1. Gunakan pre-trained model haarcascade_frontalface_default.xml untuk face detection
# 2. Gunakan pre-trained model faceNet untuk face recognition
# 3. Gunakan model CNN untuk face recognition
#
# **Anggota Kelompok :**
#
# **1. Daffa Yudisa Akbar /			NIM. 2241720008**
#
# **2. Hafizh Muhammad Rabbani /	NIM. 2241720242**
#
# **3. Joyo Sugito /				NIM. 2241720050**
#
# **4. Rendy Putra Kusuma /		NIM. 2241720124**

# %% [markdown]
# # 1. Gunakan pre-trained model haarcascade_frontalface_default.xml untuk face detection

# %%
import cv2
import matplotlib.pyplot as plt


haarcascade_path = cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
face_cascade = cv2.CascadeClassifier(haarcascade_path)


def detect_faces(image_path):

    img = cv2.imread(image_path)
    if img is None:
        print(f"Error: Unable to load image {image_path}")
        return


    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


    faces = face_cascade.detectMultiScale(
        gray,
        scaleFactor=1.1,
        minNeighbors=5,
        minSize=(30, 30)
    )

    print(f"Jumlah wajah terdeteksi: {len(faces)}")


    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)


    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


    plt.figure(figsize=(10, 8))
    plt.imshow(img_rgb)
    plt.axis("off")
    plt.title("Hasil Deteksi Wajah")
    plt.show()

# %%
image_path = "/content/drive/MyDrive/Machine_Learning/dataset_kelompok6/Train/Daffa/20241130_200019.jpg"
detect_faces(image_path)
# Out:
# Jumlah wajah terdeteksi: 1

# %%
image_path = "/content/drive/MyDrive/Machine_Learning/dataset_kelompok6/Train/Hafizh/WhatsApp Image 2024-12-03 at 11.45.07_04628036.jpg"
detect_faces(image_path)
# Out:
# Jumlah wajah terdeteksi: 1

# %%
image_path = "/content/drive/MyDrive/Machine_Learning/dataset_kelompok6/Train/Joyo/(106).jpg"
detect_faces(image_path)
# Out:
# Jumlah wajah terdeteksi: 1

# %%
image_path = "/content/drive/MyDrive/Machine_Learning/dataset_kelompok6/Train/Rendy/Rendy (14).jpg"
detect_faces(image_path)
# Out:
# Jumlah wajah terdeteksi: 1
